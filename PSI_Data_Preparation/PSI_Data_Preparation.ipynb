# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.
# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
from google.cloud import storage
import os
import tempfile
import time
from datetime import datetime
import uuid
import joblib
import uuid
from sklearn.metrics import roc_auc_score
from datetime import datetime, timedelta
import gcsfs
import duckdb as dd
import pickle
import joblib
from typing import Union
import io
path = r'C:\Users\Dwaipayan\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')
os.environ["GOOGLE_CLOUD_PROJECT"] = "prj-prod-dataplatform"
# %% [markdown]
## Configure Settings
# Set options or configurations as needed
pd.set_option('display.max_columns', None)
pd.set_option("Display.max_rows", 100)
sns.set_style('whitegrid')

# %% [markdown]
# # SIL

# %% [markdown]
# ## v1

# %% [markdown]
# ### 'Alpha - CIC-SIL-Model'

# %%
sq = """select digitalLoanAccountid, cast(prediction as string) as prediction, date(start_time) as start_time, date(end_time) as end_time, modelDisplayName, modelVersionId, calcFeature , date(publish_time) as publish_time, trenchCategory, deviceOs, Data_selection, Application_date
from prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_application
union all 
select digitalLoanAccountid, cast(prediction as string) as prediction, date(start_time) as start_time, date(end_time) as end_time, modelDisplayName, modelVersionId, calcFeature , date(publish_time) as publish_time, trenchCategory, deviceOs, 'prod' Data_selection, date(publish_time) as Application_date from prj-prod-dataplatform.audit_balance.ml_model_run_details
"""

data1 = client.query(sq).to_dataframe(progress_bar_type='tqdm')
data1.head()
# Out:
# Job ID c19e4eb2-3d15-41ee-8275-774c00abc900 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
#                    digitalLoanAccountid           prediction  start_time  \
# 0  2b400fc0-a33d-4ce8-bd9f-4df3211aaa0a         0.1551056597  2025-08-25
# 1  4a6e61ab-fb21-499d-bcea-1ce759ae890f   29398.815385066704  2025-08-25
# 2  682ed313-5304-454b-8205-a597b6617dfe    9085.312628680513  2025-08-25
# 3  d8f9f137-399c-4e72-b59a-750d19782403  0.06606221732912322  2025-08-25
# 4  edfb170a-1c00-47ee-9fea-f0ee9c54817b         0.1071477809  2025-08-25
#
#      end_time      modelDisplayName modelVersionId  \
# 0  2025-08-25   beta_demo_model_sil             v1
# 1  2025-08-25    alpha_income_model             v1
# 2  2025-08-25     beta_income_model             v1
# 3  2025-08-25  beta_stack_model_sil             v1
# 4  2025-08-25   beta_demo_model_sil             v1
#
#                                          calcFeature publish_time  \
# ...

# %%
data1.groupby(['modelDisplayName', 'modelVersionId', 'trench']).size().reset_index(name='count')
# Out:
# modelVersionId
# v2    246408
# v1    204452
# Name: count, dtype: int64

# %%
data1['modelDisplayName'] == 'modelDisplayName'
# Out:
# Index(['digitalLoanAccountid', 'prediction', 'start_time', 'end_time',
#        'modelDisplayName', 'modelVersionId', 'calcFeature', 'publish_time',
#        'trenchCategory', 'deviceOs', 'Data_selection', 'Application_date'],
#       dtype='object')
